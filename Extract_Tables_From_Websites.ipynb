# %% [markdown]
# <a href="https://colab.research.google.com/github/PraDeePP30/Scrapping_Basics/blob/main/Extract_Tables_From_Websites.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
sample_table = pd.read_html('https://en.wikipedia.org/wiki/Houston')

# %%
print(len(sample_table))
# Out:
# 19

# %%
print(sample_table[1])
# Out:
#    Climate data for Houston (Intercontinental Airport), 1991–2020 normals,[a] extremes 1888–present[b]  \
#                                                                                                  Month
# 0                                 Record high °F (°C)
# 1                                Mean maximum °F (°C)
# 2                                Average high °F (°C)
# 3                                 Average low °F (°C)
# 4                                Mean minimum °F (°C)
# 5                                  Record low °F (°C)
# 6                   Average precipitation inches (mm)
# 7              Average precipitation days (≥ 0.01 in)
# 8                       Average relative humidity (%)
# 9                           Average dew point °F (°C)
# 10                        Mean monthly sunshine hours
# 11                          Percent possible sunshine
# 12  Source: NOAA (relative humidity and dew point ...
#
# ...
